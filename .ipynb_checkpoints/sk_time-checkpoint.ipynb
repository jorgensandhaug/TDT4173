# %%
# !pip install pandas matplotlib numpy statsforecast prophet scikit-learn scipy pyarrow seaborn xgboost h2o sktime tsfresh
# Out:
# Requirement already satisfied: pandas in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: matplotlib in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: numpy in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (1.25.2)
# Requirement already satisfied: statsforecast in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (1.6.0)
# Requirement already satisfied: prophet in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (1.1.4)
# Requirement already satisfied: scikit-learn in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: scipy in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (1.11.2)
# Requirement already satisfied: pyarrow in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (13.0.0)
# Requirement already satisfied: seaborn in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: xgboost in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: h2o in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (3.42.0.3)
# Requirement already satisfied: sktime in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (0.23.0)
# Requirement already satisfied: tsfresh in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (0.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: numba>=0.55.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from statsforecast) (0.58.0)
# Requirement already satisfied: polars in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from statsforecast) (0.19.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from statsforecast) (0.14.0)
# Requirement already satisfied: tqdm in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from statsforecast) (4.66.1)
# Requirement already satisfied: fugue>=0.8.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from statsforecast) (0.8.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from prophet) (1.1.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from prophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from prophet) (2.4.0)
# Requirement already satisfied: holidays>=0.25 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from prophet) (0.33)
# Requirement already satisfied: importlib-resources in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from prophet) (6.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: requests in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from h2o) (2.31.0)
# Requirement already satisfied: tabulate in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from h2o) (0.9.0)
# Requirement already satisfied: scikit-base<0.6.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from sktime) (0.5.1)
# Requirement already satisfied: patsy>=0.4.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from tsfresh) (0.5.3)
# Requirement already satisfied: dask[dataframe]>=2.9.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from tsfresh) (2023.9.2)
# Requirement already satisfied: distributed>=2.11.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from tsfresh) (2023.9.2)
# Requirement already satisfied: stumpy>=1.7.2 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from tsfresh) (1.12.0)
# Requirement already satisfied: cloudpickle in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from tsfresh) (2.2.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: click>=8.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (2023.9.2)
# Requirement already satisfied: partd>=1.2.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from dask[dataframe]>=2.9.0->tsfresh) (6.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (1.0.6)
# Requirement already satisfied: psutil>=5.7.2 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (2.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (2.0.5)
# Requirement already satisfied: zict>=3.0.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from distributed>=2.11.0->tsfresh) (3.0.0)
# Requirement already satisfied: triad>=0.9.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.9.1)
# Requirement already satisfied: adagio>=0.2.4 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.2.4)
# Requirement already satisfied: qpd>=0.4.4 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.1.7)
# Requirement already satisfied: sqlglot in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (18.7.0)
# Requirement already satisfied: ephem>=3.7.5.3 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from numba>=0.55.0->statsforecast) (0.41.0)
# Requirement already satisfied: six in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from patsy>=0.4.1->tsfresh) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from requests->h2o) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from requests->h2o) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from requests->h2o) (2023.7.22)
# Requirement already satisfied: antlr4-python3-runtime<4.12,>=4.11.1 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.9.0->tsfresh) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from jinja2>=2.10.3->distributed>=2.11.0->tsfresh) (2.1.3)
# Requirement already satisfied: fs in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from triad>=0.9.1->fugue>=0.8.1->statsforecast) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fs->triad>=0.9.1->fugue>=0.8.1->statsforecast) (1.4.4)
# Requirement already satisfied: setuptools in /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages (from fs->triad>=0.9.1->fugue>=0.8.1->statsforecast) (68.1.2)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
y_train_a = pd.read_parquet('A/train_targets.parquet')
y_train_b = pd.read_parquet('B/train_targets.parquet')
y_train_c = pd.read_parquet('C/train_targets.parquet')

# %%
X_train_estimated_a = pd.read_parquet('A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('C/X_train_estimated.parquet')

# %%
X_train_observed_a = pd.read_parquet('A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('C/X_train_observed.parquet')

# %%
X_test_estimated_a = pd.read_parquet('A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('C/X_test_estimated.parquet')

# %% [markdown]
# # Exploratory analysis of the data

# %%
# add location features
X_train_estimated_a['location'] = 'A'
X_train_estimated_b['location'] = 'B'
X_train_estimated_c['location'] = 'C'

X_train_observed_a['location'] = 'A'
X_train_observed_b['location'] = 'B'
X_train_observed_c['location'] = 'C'

X_test_estimated_a['location'] = 'A'
X_test_estimated_b['location'] = 'B'
X_test_estimated_c['location'] = 'C'

# concat observed and estimated, then merge with y_train
X_train_a = pd.concat([X_train_estimated_a, X_train_observed_a])
X_train_b = pd.concat([X_train_estimated_b, X_train_observed_b])
X_train_c = pd.concat([X_train_estimated_c, X_train_observed_c])

# %%
import warnings

import numpy as np
import pandas as pd

# hide warnings
warnings.filterwarnings("ignore")
warnings.resetwarnings()

# %%
from sktime.registry import all_estimators

for forecaster in all_estimators(filter_tags={"scitype:y": ["multivariate", "both"]}):
    print(forecaster[0])

# %%
import numpy as np

from sktime.datasets import load_airline
from sktime.forecasting.theta import ThetaForecaster

# until fit, identical with the simple workflow
y = load_airline()

fh = np.arange(1, 13)

forecaster = ThetaForecaster(sp=12)
forecaster.fit(y, fh=fh)
# Out:
# ThetaForecaster(sp=12)

# %%
coverage = 0.9
y_pred_ints = forecaster.predict_interval(coverage=coverage)
y_pred_ints
# Out:
#         Number of airline passengers
#                                  0.9
#                                lower       upper
# 1961-01                   418.280121  464.281951
# 1961-02                   402.215881  456.888055
# 1961-03                   459.966113  522.110500
# 1961-04                   442.589309  511.399214
# 1961-05                   443.525027  518.409480
# 1961-06                   506.585814  587.087737
# 1961-07                   561.496768  647.248956
# 1961-08                   557.363322  648.062363
# 1961-09                   477.658055  573.047752
# 1961-10                   407.915090  507.775355
# 1961-11                   346.942924  451.082017
# 1961-12                   394.708221  502.957142

# %%
from sktime.utils import plotting

# also requires predictions
y_pred = forecaster.predict()

fig, ax = plotting.plot_series(
    y, y_pred, labels=["y", "y_pred"], pred_interval=y_pred_ints
)
# Out:
# ColumnEnsembleForecaster
# DynamicFactor
# EnsembleForecaster
# FhPlexForecaster
# ForecastByLevel
# ForecastKnownValues
# ForecastX
# ForecastingGridSearchCV
# ForecastingPipeline
# ForecastingRandomizedSearchCV
# ForecastingSkoptSearchCV
# HierarchyEnsembleForecaster
# IxToX
# MultiplexForecaster
# Permute
# PluginParamsForecaster
# TransformedTargetForecaster
# VAR
# VARMAX
# VECM
# YtoX
# (60, 6) (60,) (20, 6) (20,)
# Original columns: {'prob_rime:p', 'sfc_pressure:hPa', 'direct_rad_1h:J', 'fresh_snow_6h:cm', 'location', 'wind_speed_w_1000hPa:ms', 'pressure_50m:hPa', 'snow_water:kgm2', 'effective_cloud_cover:p', 'date_calc', 'fresh_snow_3h:cm', 'snow_drift:idx', 'diffuse_rad:W', 'ds', 'direct_rad:W', 'precip_5min:mm', 'sun_elevation:d', 'relative_humidity_1000hPa:p', 'wind_speed_10m:ms', 'total_cloud_cover:p', 'fresh_snow_1h:cm', 'super_cooled_liquid_water:kgm2', 'sun_azimuth:d', 'clear_sky_rad:W', 'snow_depth:cm', 'msl_pressure:hPa', 'snow_density:kgm3', 'wind_speed_v_10m:ms', 'pressure_100m:hPa', 'ceiling_height_agl:m', 'diffuse_rad_1h:J', 'air_density_2m:kgm3', 'snow_melt_10min:mm', 'absolute_humidity_2m:gm3', 'clear_sky_energy_1h:J', 't_1000hPa:K', 'elevation:m', 'visibility:m', 'is_day:idx', 'cloud_base_agl:m', 'fresh_snow_12h:cm', 'precip_type_5min:idx', 'is_in_shadow:idx', 'wind_speed_u_10m:ms', 'dew_point_2m:K', 'dew_or_rime:idx', 'rain_water:kgm2', 'fresh_snow_24h:cm'}
# Filtered columns: {'prob_rime:p', 'sfc_pressure:hPa', 'direct_rad_1h:J', 'fresh_snow_6h:cm', 'wind_speed_w_1000hPa:ms', 'pressure_50m:hPa', 'snow_water:kgm2', 'effective_cloud_cover:p', 'date_calc', 'fresh_snow_3h:cm', 'snow_drift:idx', 'diffuse_rad:W', 'ds', 'direct_rad:W', 'precip_5min:mm', 'sun_elevation:d', 'relative_humidity_1000hPa:p', 'wind_speed_10m:ms', 'total_cloud_cover:p', 'fresh_snow_1h:cm', 'super_cooled_liquid_water:kgm2', 'sun_azimuth:d', 'clear_sky_rad:W', 'snow_depth:cm', 'msl_pressure:hPa', 'snow_density:kgm3', 'wind_speed_v_10m:ms', 'pressure_100m:hPa', 'ceiling_height_agl:m', 'diffuse_rad_1h:J', 'air_density_2m:kgm3', 'snow_melt_10min:mm', 'absolute_humidity_2m:gm3', 'clear_sky_energy_1h:J', 't_1000hPa:K', 'elevation:m', 'visibility:m', 'is_day:idx', 'cloud_base_agl:m', 'fresh_snow_12h:cm', 'precip_type_5min:idx', 'is_in_shadow:idx', 'wind_speed_u_10m:ms', 'dew_point_2m:K', 'dew_or_rime:idx', 'rain_water:kgm2', 'fresh_snow_24h:cm'}
# Removed columns: {'location'}
# Expected hourly timestamps: DatetimeIndex(['2019-06-02 22:00:00', '2019-06-02 23:00:00',
#                '2019-06-03 00:00:00', '2019-06-03 01:00:00',
#                '2019-06-03 02:00:00', '2019-06-03 03:00:00',
#                '2019-06-03 04:00:00', '2019-06-03 05:00:00',
#                '2019-06-03 06:00:00', '2019-06-03 07:00:00',
#                ...
#                '2023-04-30 14:00:00', '2023-04-30 15:00:00',
#                '2023-04-30 16:00:00', '2023-04-30 17:00:00',
#                '2023-04-30 18:00:00', '2023-04-30 19:00:00',
#                '2023-04-30 20:00:00', '2023-04-30 21:00:00',
#                '2023-04-30 22:00:00', '2023-04-30 23:00:00'],
#               dtype='datetime64[ns]', length=34274, freq='H')
# Original columns: {'prob_rime:p', 'sfc_pressure:hPa', 'direct_rad_1h:J', 'fresh_snow_6h:cm', 'location', 'wind_speed_w_1000hPa:ms', 'pressure_50m:hPa', 'snow_water:kgm2', 'effective_cloud_cover:p', 'date_calc', 'fresh_snow_3h:cm', 'snow_drift:idx', 'diffuse_rad:W', 'ds', 'direct_rad:W', 'precip_5min:mm', 'sun_elevation:d', 'relative_humidity_1000hPa:p', 'wind_speed_10m:ms', 'total_cloud_cover:p', 'fresh_snow_1h:cm', 'super_cooled_liquid_water:kgm2', 'sun_azimuth:d', 'clear_sky_rad:W', 'snow_depth:cm', 'msl_pressure:hPa', 'snow_density:kgm3', 'wind_speed_v_10m:ms', 'pressure_100m:hPa', 'ceiling_height_agl:m', 'diffuse_rad_1h:J', 'air_density_2m:kgm3', 'snow_melt_10min:mm', 'absolute_humidity_2m:gm3', 'clear_sky_energy_1h:J', 't_1000hPa:K', 'elevation:m', 'visibility:m', 'is_day:idx', 'cloud_base_agl:m', 'fresh_snow_12h:cm', 'precip_type_5min:idx', 'is_in_shadow:idx', 'wind_speed_u_10m:ms', 'dew_point_2m:K', 'dew_or_rime:idx', 'rain_water:kgm2', 'fresh_snow_24h:cm'}
# Filtered columns: {'prob_rime:p', 'sfc_pressure:hPa', 'direct_rad_1h:J', 'fresh_snow_6h:cm', 'wind_speed_w_1000hPa:ms', 'pressure_50m:hPa', 'snow_water:kgm2', 'effective_cloud_cover:p', 'date_calc', 'fresh_snow_3h:cm', 'snow_drift:idx', 'diffuse_rad:W', 'ds', 'direct_rad:W', 'precip_5min:mm', 'sun_elevation:d', 'relative_humidity_1000hPa:p', 'wind_speed_10m:ms', 'total_cloud_cover:p', 'fresh_snow_1h:cm', 'super_cooled_liquid_water:kgm2', 'sun_azimuth:d', 'clear_sky_rad:W', 'snow_depth:cm', 'msl_pressure:hPa', 'snow_density:kgm3', 'wind_speed_v_10m:ms', 'pressure_100m:hPa', 'ceiling_height_agl:m', 'diffuse_rad_1h:J', 'air_density_2m:kgm3', 'snow_melt_10min:mm', 'absolute_humidity_2m:gm3', 'clear_sky_energy_1h:J', 't_1000hPa:K', 'elevation:m', 'visibility:m', 'is_day:idx', 'cloud_base_agl:m', 'fresh_snow_12h:cm', 'precip_type_5min:idx', 'is_in_shadow:idx', 'wind_speed_u_10m:ms', 'dew_point_2m:K', 'dew_or_rime:idx', 'rain_water:kgm2', 'fresh_snow_24h:cm'}
# Removed columns: {'location'}
# Original columns: {'prob_rime:p', 'sfc_pressure:hPa', 'direct_rad_1h:J', 'fresh_snow_6h:cm', 'location', 'wind_speed_w_1000hPa:ms', 'pressure_50m:hPa', 'snow_water:kgm2', 'effective_cloud_cover:p', 'date_calc', 'fresh_snow_3h:cm', 'snow_drift:idx', 'diffuse_rad:W', 'ds', 'direct_rad:W', 'precip_5min:mm', 'sun_elevation:d', 'relative_humidity_1000hPa:p', 'wind_speed_10m:ms', 'total_cloud_cover:p', 'fresh_snow_1h:cm', 'super_cooled_liquid_water:kgm2', 'sun_azimuth:d', 'clear_sky_rad:W', 'snow_depth:cm', 'msl_pressure:hPa', 'snow_density:kgm3', 'wind_speed_v_10m:ms', 'pressure_100m:hPa', 'ceiling_height_agl:m', 'diffuse_rad_1h:J', 'air_density_2m:kgm3', 'snow_melt_10min:mm', 'absolute_humidity_2m:gm3', 'clear_sky_energy_1h:J', 't_1000hPa:K', 'elevation:m', 'visibility:m', 'is_day:idx', 'cloud_base_agl:m', 'fresh_snow_12h:cm', 'precip_type_5min:idx', 'is_in_shadow:idx', 'wind_speed_u_10m:ms', 'dew_point_2m:K', 'dew_or_rime:idx', 'rain_water:kgm2', 'fresh_snow_24h:cm'}
# Filtered columns: {'prob_rime:p', 'sfc_pressure:hPa', 'direct_rad_1h:J', 'fresh_snow_6h:cm', 'wind_speed_w_1000hPa:ms', 'pressure_50m:hPa', 'snow_water:kgm2', 'effective_cloud_cover:p', 'date_calc', 'fresh_snow_3h:cm', 'snow_drift:idx', 'diffuse_rad:W', 'ds', 'direct_rad:W', 'precip_5min:mm', 'sun_elevation:d', 'relative_humidity_1000hPa:p', 'wind_speed_10m:ms', 'total_cloud_cover:p', 'fresh_snow_1h:cm', 'super_cooled_liquid_water:kgm2', 'sun_azimuth:d', 'clear_sky_rad:W', 'snow_depth:cm', 'msl_pressure:hPa', 'snow_density:kgm3', 'wind_speed_v_10m:ms', 'pressure_100m:hPa', 'ceiling_height_agl:m', 'diffuse_rad_1h:J', 'air_density_2m:kgm3', 'snow_melt_10min:mm', 'absolute_humidity_2m:gm3', 'clear_sky_energy_1h:J', 't_1000hPa:K', 'elevation:m', 'visibility:m', 'is_day:idx', 'cloud_base_agl:m', 'fresh_snow_12h:cm', 'precip_type_5min:idx', 'is_in_shadow:idx', 'wind_speed_u_10m:ms', 'dew_point_2m:K', 'dew_or_rime:idx', 'rain_water:kgm2', 'fresh_snow_24h:cm'}
# Removed columns: {'location'}
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

from sktime.datasets import load_arrow_head, load_basic_motions
from sktime.transformations.panel.tsfresh import TSFreshFeatureExtractor
X, y = load_basic_motions(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
#  multivariate input data
X_train.head()
# Out:
#                                                 dim_0  \
# 73  0     -2.488524
# 1     -2.488524
# 2     -3.29834...
# 44  0     0.354481
# 1     0.354481
# 2     0.449142
# 3...
# 3   0     0.289855
# 1     0.289855
# 2    -0.669185
# 3...
# 70  0     -0.623875
# 1     -0.623875
# 2     -1.08152...
# 46  0     1.275129
# 1     1.275129
# 2    -0.273185
# 3...
#
#                                                 dim_1  \
# 73  0      0.360353
# 1      0.360353
# 2     -4.12351...
# 44  0    -0.567671
# 1    -0.567671
# 2    -1.899854
# 3...
# 3   0     0.284130
# 1     0.284130
# 2    -0.210466
# 3...
# 70  0     -2.123436
# 1     -2.123436
# 2     -0.12151...
# 46  0    -1.024406
# 1    -1.024406
# 2     0.095152
# 3...
#
#                                                 dim_2  \
# 73  0      0.362847
# 1      0.362847
# 2      1.90192...
# 44  0    -0.084270
# 1    -0.084270
# 2     0.913056
# 3...
# 3   0     0.213680
# 1     0.213680
# 2     0.252267
# 3...
# 70  0     -0.513654
# 1     -0.513654
# 2      0.80946...
# 46  0    -0.545722
# 1    -0.545722
# 2     0.023203
# 3...
#
#                                                 dim_3  \
# 73  0      0.007990
# 1      0.007990
# 2     -0.23437...
# 44  0    -0.223723
# 1    -0.223723
# 2     0.692477
# 3...
# 3   0    -0.314278
# 1    -0.314278
# 2     0.018644
# 3...
# 70  0     -0.143822
# 1     -0.143822
# 2     -1.08132...
# 46  0    -0.463427
# 1    -0.463427
# 2     0.042614
# 3...
#
#                                                 dim_4  \
# 73  0     -0.093218
# 1     -0.093218
# 2      0.34623...
# 44  0    -0.247694
# 1    -0.247694
# 2     0.149149
# 3...
# 3   0     0.074574
# 1     0.074574
# 2     0.007990
# 3...
# 70  0     0.058594
# 1     0.058594
# 2    -0.127842
# 3...
# 46  0    -0.367545
# 1    -0.367545
# 2    -0.109198
# 3...
#
#                                                 dim_5
# 73  0      0.844289
# 1      0.844289
# 2      0.43945...
# 44  0     0.050604
# 1     0.050604
# 2     0.849616
# 3...
# 3   0    -0.079901
# 1    -0.079901
# 2     0.237040
# 3...
# 70  0      1.086656
# 1      1.086656
# 2      0.06658...
# 46  0    -0.159802
# 1    -0.159802
# 2     0.183773
# 3...

# %%
t = TSFreshFeatureExtractor(default_fc_parameters="efficient", show_warnings=False)
Xt = t.fit_transform(X_train)
# Out:
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/sktime/datatypes/_panel/_convert.py:823: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   idx_df = X[[c]].applymap(lambda x: x.index).explode(c)
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/sktime/datatypes/_panel/_convert.py:823: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   idx_df = X[[c]].applymap(lambda x: x.index).explode(c)
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/sktime/datatypes/_panel/_convert.py:823: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   idx_df = X[[c]].applymap(lambda x: x.index).explode(c)
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/sktime/datatypes/_panel/_convert.py:823: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   idx_df = X[[c]].applymap(lambda x: x.index).explode(c)
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/sktime/datatypes/_panel/_convert.py:823: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   idx_df = X[[c]].applymap(lambda x: x.index).explode(c)
# /Users/jorgensandhaug/Library/Mobile Documents/com~apple~CloudDocs/indok/indok_4/ml/.venv/lib/python3.11/site-packages/sktime/datatypes/_panel/_convert.py:823: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   idx_df = X[[c]].applymap(lambda x: x.index).explode(c)
# Feature Extraction: 100%|██████████| 360/360 [00:05<00:00, 63.08it/s]

# %%
data_by_location = {
    'A': {'X_train': X_train_a, 'y_train': y_train_a},
    'B': {'X_train': X_train_b, 'y_train': y_train_b},
    'C': {'X_train': X_train_c, 'y_train': y_train_c},
}

# convert all datetime columns to datetime type
for location in data_by_location:
    X_train = data_by_location[location]['X_train']
    X_train['ds'] = pd.to_datetime(X_train['date_forecast'])
    X_train.drop(columns=['date_forecast'], inplace=True)
    # y_train has "time" instead
    y_train = data_by_location[location]['y_train']
    y_train['ds'] = pd.to_datetime(y_train['time'])
    y_train.drop(columns=['time'], inplace=True)

# %%
from sktime.transformations.compose import TransformerPipeline
from sktime.transformations.series.impute import Imputer
from sklearn.impute import SimpleImputer as SklearnSimpleImputer



# For exogenous variables (X_train)
exog_imputer = SklearnSimpleImputer(strategy="mean")  # or any other strategy like 'median', 'most_frequent', etc.

#X_train_a_imputed = exog_imputer.fit_transform(X_train_a)

imputer = Imputer(method="mean")

y_train = data_by_location['A']['y_train']
X_train = data_by_location['A']['X_train']


# Original columns in the DataFrame
original_columns = set(X_train.columns)

# Perform the dtype selection
X_train_filtered = X_train.select_dtypes(exclude=['object'])

# Columns after filtering
filtered_columns = set(X_train_filtered.columns)

# Find the columns that were removed
removed_columns = original_columns - filtered_columns
import sys

sys.stdout.write(f"Original columns: {original_columns}\n")
sys.stdout.write(f"Filtered columns: {filtered_columns}\n")
sys.stdout.write(f"Removed columns: {removed_columns}\n")

print(f"Original columns: {original_columns}")
print(f"Filtered columns: {filtered_columns}")
print(f"Removed columns: {removed_columns}")












# start_date = y_train['ds'].min()
# end_date = y_train['ds'].max()
# expected_hourly_timestamps = pd.date_range(start=start_date, end=end_date, freq='H')

# print(f"Expected hourly timestamps: {expected_hourly_timestamps}")

# missing_timestamps = expected_hourly_timestamps[~expected_hourly_timestamps.isin(y_train['ds'])]

# y_train_a_imputed = target_imputer.fit_transform(X=X_train, y=y_train)
# missing_timestamps_after = expected_hourly_timestamps[~expected_hourly_timestamps.isin(y_train_a_imputed['ds'])]
# missing_timestamps_after
#y_train_a_imputed



# for location, data in data_by_location.items():
#     X_train = data['X_train'].copy()  # To ensure original dataframes are not changed
#     y_train = data['y_train'].copy()

#     # Apply target imputation transformations for y_train
#     y_train_imputed = target_imputer.fit_transform(y_train)
    
#     # Apply exogenous variable imputation transformations for X_train
#     X_train_imputed = exog_imputer.fit_transform(X_train)
    
#     # Update the data dictionary with imputed data
#     data['y_train_imputed'] = y_train_imputed
#     data['X_train_imputed'] = X_train_imputed
